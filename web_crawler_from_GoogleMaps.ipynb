# %% [markdown]
# ## Get places using google maps

# %%
import googlemaps
import numpy as np
import pandas as pd
import math
import json

# %%
#Open a google maps client

YourApiKey = 'AIzaS.................' #provide your Google Maps API key here  

gm = googlemaps.Client(YourApiKey)

# %%
## Create a grid in Lat Lon space


def meters_to_lat(meters):
    """
    Convert meters to a crude latitude-longitude measure, 
    using the unit longitude distance at the equator
    """
    return meters/111.2e3

def meters_to_long_melCBD(meters):
    """
    Convert meters to a crude longitude measure in melbourne cbd, 
    using the unit longitude distance at the equator
    """
    return (4/3.16) * (meters/111.2e3)

def lat_to_meters(la):
    """
    Convert meters to a crude latitude-longitude measure, 
    using the unit longitude distance at the equator
    """
    return la * 111.2e3

def long_melCBD_to_meters(lon):
    """
    Convert meters to a crude longitude measure in melbourne cbd, 
    using the unit longitude distance at the equator
    """
    return lon * 111.2e3 * (3.16/4)

def create_grids(ulLatLon, lrLatLon, meters_spacing = 400., shape=()):
    """
    This function creates a set of cells defined by a rectangle, and spacing in meters.
    It return the coordinates of the cell centers - 
        which are the points where we conduct our places_nearby() searches
        
    Note that the overall cell soze will be slightly smaller meters_spacing paramter, 
    as I use : nx = int(np.ceil((lrLatLon[1] - ulLatLon[1])/lldist))
               xs = np.linspace(ulLatLon[1], lrLatLon[1], nx)
    Alternatively a shape tuple can be provide, eg (3, 5) defining the size of the grid. 
 
    
    """
    if not shape:
        lldist = meters_to_lat(meters_spacing)
        print ('lldist:', lldist)
        lldist_long = meters_to_long_melCBD(meters_spacing)
        print ('lldist_long:', lldist_long)
        #nx = int(abs(np.ceil((lrLatLon[1] - ulLatLon[1])/lldist_long)))
        nx = int(np.ceil(abs((lrLatLon[1] - ulLatLon[1])/lldist_long)))
        print ('nx:', nx)
        #ny = int(abs(np.ceil((lrLatLon[0] - ulLatLon[0])/lldist)))
        ny = int(np.ceil(abs((lrLatLon[0] - ulLatLon[0])/lldist)))
        print ('ny:', ny)
        xs, lldist_x = np.linspace(ulLatLon[1], lrLatLon[1], nx, endpoint=False, retstep=True)
        #print 'xs:', xs
        ys, lldist_y =  np.linspace(ulLatLon[0], lrLatLon[0], ny, endpoint=False, retstep=True)
        #print 'ys:', ys
        if nx == 1:
            xs = []
            xs.append(ulLatLon[1])
            lldist_x = lrLatLon[1] - ulLatLon[1]
        if ny == 1:
            ys = []
            ys.append(ulLatLon[0])
            lldist_y = lrLatLon[0] - ulLatLon[0]
            
    else:
        #lldist = meters_to_lat(meters_spacing)
        #xs, lldist_x = np.linspace(ulLatLon[1], lrLatLon[1], shape[0], endpoint=False, retstep=True)
        #ys, lldist_y =  np.linspace(ulLatLon[0], lrLatLon[0], shape[1], endpoint=False, retstep=True)
        xs, lldist_x = np.linspace(ulLatLon[1], lrLatLon[1], shape[1], endpoint=False, retstep=True)
        ys, lldist_y =  np.linspace(ulLatLon[0], lrLatLon[0], shape[0], endpoint=False, retstep=True)
        #nx = shape[0]
        nx = shape[1]
        if nx == 1:
            xs = []
            xs.append(ulLatLon[1])
            lldist_x = lrLatLon[1] - ulLatLon[1]
        #ny = shape[1]
        ny = shape[0]
        if ny == 1:
            ys = []
            ys.append(ulLatLon[0])
            lldist_y = lrLatLon[0] - ulLatLon[0]
    X, Y = np.meshgrid(xs , ys) #Thes are coordinates of the cell vertices
    subX, subY = np.copy(X), np.copy(Y)
    #subX = subX[:-1, :-1] + lldist/2. #These give the points at the centre of the cells
    #subY = subY[:-1, :-1] + lldist/2.
    subX = subX + lldist_x/2. #These give the points at the centre of the cells
    subY = subY + lldist_y/2.
    return subX, subY, lldist_x, lldist_y

# %%
y = -37.8091677
x = 144.9684903
places  = gm.places_nearby(keyword='cafe', location=(y,x), radius=5)#new_spacing*math.sqrt(2) )
df = pd.DataFrame(columns=['name', 'lat', 'lon', 'rating','place_id'])
RecordsAll = []
RecordsAll.append(places['results'])  
for cell in RecordsAll:
    for place in cell:
        #print(place)
        name = place['name'].encode('utf-8')
        lat = place['geometry']['location']['lat']
        lon = place['geometry']['location']['lng']
        place_id=place['place_id'].encode('utf-8')
        try:
            rating = place['rating'] #Not all places have ratings, so use try - except
        except:
            rating = ''
        series = pd.Series([name, lat, lon, rating,place_id], index=['name', 'lat', 'lon', 'rating','place_id'])
        df = df.append(series,  ignore_index=True)
print(name, lat, lon, rating)
df.head()
df2 = df.drop_duplicates('place_id')
df2.shape
print (df2)
#output to csv
df2.to_csv('results-xx.csv')
# Out:
# b'Jack Sprat Cafe' -37.8086019 144.9684545 4.4
#                               name        lat         lon rating  \
# 0          b'Beyond Internet cafe' -37.809524  144.966885      0
# 1   b'The League of Honest Coffee' -37.809243  144.968448    4.5
# 2               b'65 Degrees Cafe' -37.808741  144.968724    4.4
# 3                  b'Barista Cafe' -37.809500  144.969702    4.2
# 4                b'Blu Point Cafe' -37.808391  144.966355    4.6
# 5                 b"B & B 's Cafe" -37.808845  144.968812      2
# 6               b'THE J Walk Cafe' -37.810329  144.967674      4
# 7                b'Global Kitchen' -37.808602  144.968455    3.9
# 8                b'Cafe Caledonia' -37.810713  144.968668    4.6
# 9               b'No Vacancy Cafe' -37.810375  144.965973    3.8
# 10             b'Traveller Coffee' -37.811417  144.971246    4.7
# 11              b'Jack Sprat Cafe' -37.808602  144.968455    4.4
#
#                           place_id
# 0   b'ChIJR96FVslC1moRErMxY6o1lhQ'
# 1   b'ChIJ71r4xc5C1moRVjrA0cOSPuA'
# 2   b'ChIJacSRws5C1moRYYrJ9EeuiIY'
# 3   b'ChIJz53zK89C1moR7pdsPwDE5m0'
# 4   b'ChIJ7ZtyG8xC1moRJjQdSUCcv6k'
# 5   b'ChIJIw7Z3M5C1moRKdkmjUXgdwk'
# 6   b'ChIJWQciQslC1moRxHjfNED7hfY'
# 7   b'ChIJZ9tL785C1moRQ9fS18QxHis'
# 8   b'ChIJucpkO8lC1moRfpwSaONdsUs'
# 9   b'ChIJ6erp3ctC1moRcYQ5bNFgaw0'
# 10  b'ChIJcRZauchC1moRSvqNA1_Mgwk'
# 11  b'ChIJPT3E6M5C1moRJcwkpQ_bsN8'

# %%
##########
#In this block we search through a grid and extract records cel-by-cell. 
#If the records query in anny cell maxes out (i.e. hits 20 record), 
#we create a finer grid and search again
########## -37.8091677,144.9684903      #melbourne university -37.80004479999999,144.9600488
##
#https://maps.googleapis.com/maps/api/geocode/json?address=Melbourne%20University&key=AIza.........
###


ULCRN = (-37.80004479999999+meters_to_lat(1000), 144.9600488-meters_to_long_melCBD(1000)) #Approx melbourne CBD limits
LRCRN = (-37.80004479999999-meters_to_lat(1000), 144.9600488+meters_to_long_melCBD(1000))



spacing = 200. #intial spacing of cells in our grid
X, Y, lldist_x, lldist_y = create_grids(ULCRN, LRCRN, meters_spacing = spacing, shape=()) #create grids; meters_spacing no use 
print ('lldist_x1: ', lldist_x)
print ('lldist_y1: ', lldist_y)
orig_shape = Y.shape
print ('orig_shape: ',orig_shape)
max_levels = 2000. #this paramter will limit the number of refinement levels 
lengths = [21]  #A dummy parameter, ultimately we try to reduce this below 20, meaning we have 
                #will have returned all results for each searhc area
fac = 1.        #This is the scaling factor for our grid cell size and search radius

indexMatrixDictList = []
#indexMatrixDictParent = {}
#indexMatrixDictNow = {}
isfirstrun = True
needFurtherDivision = True
RecordsAll = []

while needFurtherDivision and (len(lengths) == 0 or max(lengths) >= 20) and fac <= max_levels:
    needFurtherDivision = False
    print('##Iteration at grid level: ' + str(int(fac)))
    new_shape = tuple(np.array(orig_shape)*fac)
    print ('new_shape: ',new_shape)
    new_spacing = spacing/fac
    #print('##Search radius in meters: ' + str(new_spacing))
    #records = []
    lengths = []
    X, Y, lldist_x, lldist_y = create_grids(ULCRN, LRCRN, meters_spacing = new_spacing, shape=new_shape)#create grids; meters_spacing no use -Hz
    print ('lldist_x: ', lldist_x)
    print ('lldist_y: ', lldist_y)
    longmeters = long_melCBD_to_meters(abs(lldist_x))
    print ('longmeters: ',longmeters)
    latmeters  = lat_to_meters(abs(lldist_y))
    print ('latmeters: ',latmeters)
    radius_r = 0.5 * math.sqrt(longmeters*longmeters + latmeters*latmeters)#+2
    radius_r = math.ceil(radius_r)+20
    print ('radius_r: ', radius_r)
    print('##Search radius in meters: ' + str(radius_r))
    print ('new_spacing: ', new_spacing)
    #print(X.shape)
    if isfirstrun:
        isfirstrun = False
        indexMatrixDictNow = {}
        for index, value in np.ndenumerate(X): #loop through cells of current grid            
            print (index)
            y = Y[index]
            x = X[index]
            #print(x,y, new_spacing)
            places  = gm.places_nearby(keyword='supermarket', location=(y,x), radius=radius_r)#, type='grocery_or_supermarket')#,type='cafe')#new_spacing*math.sqrt(2) )
            #places=gm.places_autocomplete_query("supermarket near Melbourne University", location=(y,x), radius=radius_r)
            #places=gm.places("supermarket near Melbourne University", location=(y,x), radius=radius_r)#,type="grocery_or_supermarket")
            #records.append(places['results'])
            print(len(places['results']))
            print ("places", places)
            if(len(places['results']) >= 20):
                needFurtherDivision = True
                indexMatrixDictNow[index] = 1 #1 for need further division
                lengths.append(len(places['results']))
            else:
                indexMatrixDictNow[index] = -1 #-1 for no need further division
                RecordsAll.append(places['results'])               
        
        indexMatrixDictList.append(indexMatrixDictNow)
        
    else:
        isfirstrun = False        
        indexMatrixDictParent = indexMatrixDictList[-1]
        indexMatrixDictNow = {}
        for index, value in indexMatrixDictParent.iteritems():
            a = index[0]
            b = index[1]
            V_2a = 2 * a
            V_2b = 2 * b
            V_2a_1 = 2 * a + 1
            V_2b_1 = 2 * b + 1
            index00 = (V_2a,V_2b)
            index01 = (V_2a,V_2b_1)
            index10 = (V_2a_1,V_2b)
            index11 = (V_2a_1,V_2b_1)
            if value < 0:
                indexMatrixDictNow[index00] = -1
                indexMatrixDictNow[index01] = -1
                indexMatrixDictNow[index10] = -1
                indexMatrixDictNow[index11] = -1
            else:
                indexMatrixDictNow[index00] = 1
                indexMatrixDictNow[index01] = 1
                indexMatrixDictNow[index10] = 1
                indexMatrixDictNow[index11] = 1                
        
        for index, value in np.ndenumerate(X): #loop through cells of current grid
            #print index,
            if indexMatrixDictNow[index] > 0:
                y = Y[index]
                x = X[index]
                #print(x,y, new_spacing)
                places  = gm.places_nearby(keyword='supermarket', location=(y,x), radius=radius_r)#, type='grocery_or_supermarket')#,type='cafe')#new_spacing*math.sqrt(2) )
                #places=gm.places_autocomplete_query("supermarket near Melbourne University",  location=(y,x), radius=radius_r)
                #places=gm.places( "supermarket near Melbourne University", location=(y,x), radius=radius_r)#,type="grocery_or_supermarket")
                #records.append(places['results'])
                print (index)
                print(len(places['results']))
                if(len(places['results']) >= 20):
                    needFurtherDivision = True
                    indexMatrixDictNow[index] = 1
                    lengths.append(len(places['results']))
                else:
                    indexMatrixDictNow[index] = -1
                    RecordsAll.append(places['results'])               
        
        indexMatrixDictList.append(indexMatrixDictNow)
        
    fac *= 2 #Increase the grid refinment factor
print('##finished')
import datetime
t=datetime.datetime.now().strftime("%Y-%m-%d %H-%M-%S")
# Out:
# lldist: 0.0017985611510791368
# lldist_long: 0.0022766596849102994
# nx: 11
# ny: 11
# lldist_x1:  0.002069690622647613
# lldist_y1:  -0.0016350555918904774
# orig_shape:  (11, 11)
# ##Iteration at grid level: 1
# new_shape:  (11.0, 11.0)
# lldist_x:  0.002069690622647613
# lldist_y:  -0.0016350555918904774
# longmeters:  181.8181818183475
# latmeters:  181.8181818182211
# radius_r:  149
# ##Search radius in meters: 149
# new_spacing:  200.0
# (0, 0)
# C:\Users\Hao\Anaconda3\lib\site-packages\ipykernel_launcher.py:73: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
# C:\Users\Hao\Anaconda3\lib\site-packages\ipykernel_launcher.py:74: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (0, 1)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (0, 2)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (0, 3)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (0, 4)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (0, 5)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (0, 6)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (0, 7)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (0, 8)
# 2
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7927456, 'lng': 144.9695322}, 'viewport': {'northeast': {'lat': -37.79139577010728, 'lng': 144.9708820298927}, 'southwest': {'lat': -37.79409542989272, 'lng': 144.9681823701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'e6a9e86c14c769be1bee117d03a91394a5fc1692', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 3.2, 'reference': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Princes St & Drummond St, Carlton'}, {'geometry': {'location': {'lat': -37.7927445, 'lng': 144.9695346}, 'viewport': {'northeast': {'lat': -37.79132872010728, 'lng': 144.9702835298928}, 'southwest': {'lat': -37.79402837989272, 'lng': 144.9675838701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '98c15f97919ca08028ab3c43bb4a160534e592ab', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJHbHg3yhD1moRtigMFWQSBaY', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 0, 'reference': 'ChIJHbHg3yhD1moRtigMFWQSBaY', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '570 Lygon St, Carlton'}], 'status': 'OK'}
# (0, 9)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7927456, 'lng': 144.9695322}, 'viewport': {'northeast': {'lat': -37.79139577010728, 'lng': 144.9708820298927}, 'southwest': {'lat': -37.79409542989272, 'lng': 144.9681823701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'e6a9e86c14c769be1bee117d03a91394a5fc1692', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 3.2, 'reference': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Princes St & Drummond St, Carlton'}], 'status': 'OK'}
# (0, 10)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7927456, 'lng': 144.9695322}, 'viewport': {'northeast': {'lat': -37.79139577010728, 'lng': 144.9708820298927}, 'southwest': {'lat': -37.79409542989272, 'lng': 144.9681823701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'e6a9e86c14c769be1bee117d03a91394a5fc1692', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 3.2, 'reference': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Princes St & Drummond St, Carlton'}], 'status': 'OK'}
# (1, 0)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (1, 1)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (1, 2)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (1, 3)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (1, 4)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (1, 5)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (1, 6)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (1, 7)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (1, 8)
# 2
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7927456, 'lng': 144.9695322}, 'viewport': {'northeast': {'lat': -37.79139577010728, 'lng': 144.9708820298927}, 'southwest': {'lat': -37.79409542989272, 'lng': 144.9681823701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'e6a9e86c14c769be1bee117d03a91394a5fc1692', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 3.2, 'reference': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Princes St & Drummond St, Carlton'}, {'geometry': {'location': {'lat': -37.7927445, 'lng': 144.9695346}, 'viewport': {'northeast': {'lat': -37.79132872010728, 'lng': 144.9702835298928}, 'southwest': {'lat': -37.79402837989272, 'lng': 144.9675838701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '98c15f97919ca08028ab3c43bb4a160534e592ab', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJHbHg3yhD1moRtigMFWQSBaY', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 0, 'reference': 'ChIJHbHg3yhD1moRtigMFWQSBaY', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '570 Lygon St, Carlton'}], 'status': 'OK'}
# (1, 9)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7927456, 'lng': 144.9695322}, 'viewport': {'northeast': {'lat': -37.79139577010728, 'lng': 144.9708820298927}, 'southwest': {'lat': -37.79409542989272, 'lng': 144.9681823701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'e6a9e86c14c769be1bee117d03a91394a5fc1692', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 3.2, 'reference': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Princes St & Drummond St, Carlton'}], 'status': 'OK'}
# (1, 10)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7927456, 'lng': 144.9695322}, 'viewport': {'northeast': {'lat': -37.79139577010728, 'lng': 144.9708820298927}, 'southwest': {'lat': -37.79409542989272, 'lng': 144.9681823701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'e6a9e86c14c769be1bee117d03a91394a5fc1692', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 3.2, 'reference': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Princes St & Drummond St, Carlton'}], 'status': 'OK'}
# (2, 0)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7982686, 'lng': 144.9465027}, 'viewport': {'northeast': {'lat': -37.79699792010727, 'lng': 144.9478365298927}, 'southwest': {'lat': -37.79969757989272, 'lng': 144.9451368701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'd20a6d08e35d7829698a88372367473d9957093e', 'name': 'North Melbourne Milk Bar & Wine Gourmet', 'place_id': 'ChIJ4bv-Ojtd1moR0Fxso3VWbdk', 'plus_code': {'compound_code': '6W2W+MJ North Melbourne, Victoria, Australia', 'global_code': '4RJ66W2W+MJ'}, 'rating': 3.4, 'reference': 'ChIJ4bv-Ojtd1moR0Fxso3VWbdk', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '48 Haines St, North Melbourne'}], 'status': 'OK'}
# (2, 1)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (2, 2)
# 0
# places {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# (2, 3)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (2, 4)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (2, 5)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (2, 6)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (2, 7)
# 2
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7980553, 'lng': 144.9682563}, 'viewport': {'northeast': {'lat': -37.79680162010728, 'lng': 144.9698671298927}, 'southwest': {'lat': -37.79950127989272, 'lng': 144.9671674701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '1f0cd36222a1424f0990f93a531616bfcb8cabf1', 'name': 'Woolworths Carlton', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109015799363771978289/photos">Brendan Josey</a>'], 'photo_reference': 'CmRaAAAAPshHk5MLLBv3tCdkx0RzfepWIEGd9kHQ3GaUOyEpS1OAK0mlRvuaEg8Go_70JmkmU719imOIY4qYIOPVBVITqz06c-MU6Wdf06oVolj_mZ-25zEf4Ur8SfSiLUw98zhbEhAzObfh9PMb9e286yxg9-qRGhREWmjlKWFdlVm-CHSY-nIC9UM04A', 'width': 4032}], 'place_id': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'plus_code': {'compound_code': '6X29+Q8 Carlton, Victoria, Australia', 'global_code': '4RJ66X29+Q8'}, 'price_level': 1, 'rating': 4.1, 'reference': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Lygon Court, 368-380 Lygon St, Carlton'}, {'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (2, 8)
# 3
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7980553, 'lng': 144.9682563}, 'viewport': {'northeast': {'lat': -37.79680162010728, 'lng': 144.9698671298927}, 'southwest': {'lat': -37.79950127989272, 'lng': 144.9671674701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '1f0cd36222a1424f0990f93a531616bfcb8cabf1', 'name': 'Woolworths Carlton', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109015799363771978289/photos">Brendan Josey</a>'], 'photo_reference': 'CmRaAAAApYFRJ7K1Y-r-fted-KhLJtXagGv3OggiObKnAk1Wqexw7OLF9qJWlNPhn6kecaG-80dVynlg2Mq5BmY8yUzAMLSLdP2jXJDHBMfRngipuqvjrhSvaOD3r0971A7kwyQoEhDfOucqvd_x-H4eomYQdbZBGhQmmb361KjAFDGxT7ZAGOrP5E5kXA', 'width': 4032}], 'place_id': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'plus_code': {'compound_code': '6X29+Q8 Carlton, Victoria, Australia', 'global_code': '4RJ66X29+Q8'}, 'price_level': 1, 'rating': 4.1, 'reference': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Lygon Court, 368-380 Lygon St, Carlton'}, {'geometry': {'location': {'lat': -37.7927456, 'lng': 144.9695322}, 'viewport': {'northeast': {'lat': -37.79139577010728, 'lng': 144.9708820298927}, 'southwest': {'lat': -37.79409542989272, 'lng': 144.9681823701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'e6a9e86c14c769be1bee117d03a91394a5fc1692', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 3.2, 'reference': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Princes St & Drummond St, Carlton'}, {'geometry': {'location': {'lat': -37.7927445, 'lng': 144.9695346}, 'viewport': {'northeast': {'lat': -37.79132872010728, 'lng': 144.9702835298928}, 'southwest': {'lat': -37.79402837989272, 'lng': 144.9675838701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '98c15f97919ca08028ab3c43bb4a160534e592ab', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJHbHg3yhD1moRtigMFWQSBaY', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 0, 'reference': 'ChIJHbHg3yhD1moRtigMFWQSBaY', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '570 Lygon St, Carlton'}], 'status': 'OK'}
# (2, 9)
# 3
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7980553, 'lng': 144.9682563}, 'viewport': {'northeast': {'lat': -37.79680162010728, 'lng': 144.9698671298927}, 'southwest': {'lat': -37.79950127989272, 'lng': 144.9671674701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '1f0cd36222a1424f0990f93a531616bfcb8cabf1', 'name': 'Woolworths Carlton', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109015799363771978289/photos">Brendan Josey</a>'], 'photo_reference': 'CmRaAAAAP2aMxUVamirZQFunaINI88faTkIgjUGg9faUomYQnigaB0r021AuWigl3t824Pu94BEzwVLIzpJ4ge-zbnkIyEugTFA2OzdGAcq7gd35yVa66lgnp-0MMS9_iG96WIVxEhCCftcSF_6f-doZAo5HRMmIGhRkBrxI0NU-q0a6xBdLQIF2A3DTYg', 'width': 4032}], 'place_id': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'plus_code': {'compound_code': '6X29+Q8 Carlton, Victoria, Australia', 'global_code': '4RJ66X29+Q8'}, 'price_level': 1, 'rating': 4.1, 'reference': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Lygon Court, 368-380 Lygon St, Carlton'}, {'geometry': {'location': {'lat': -37.7927456, 'lng': 144.9695322}, 'viewport': {'northeast': {'lat': -37.79139577010728, 'lng': 144.9708820298927}, 'southwest': {'lat': -37.79409542989272, 'lng': 144.9681823701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'e6a9e86c14c769be1bee117d03a91394a5fc1692', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 3.2, 'reference': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Princes St & Drummond St, Carlton'}, {'geometry': {'location': {'lat': -37.7927445, 'lng': 144.9695346}, 'viewport': {'northeast': {'lat': -37.79132872010728, 'lng': 144.9702835298928}, 'southwest': {'lat': -37.79402837989272, 'lng': 144.9675838701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '98c15f97919ca08028ab3c43bb4a160534e592ab', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJHbHg3yhD1moRtigMFWQSBaY', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 0, 'reference': 'ChIJHbHg3yhD1moRtigMFWQSBaY', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '570 Lygon St, Carlton'}], 'status': 'OK'}
# (2, 10)
# 3
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7980553, 'lng': 144.9682563}, 'viewport': {'northeast': {'lat': -37.79680162010728, 'lng': 144.9698671298927}, 'southwest': {'lat': -37.79950127989272, 'lng': 144.9671674701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '1f0cd36222a1424f0990f93a531616bfcb8cabf1', 'name': 'Woolworths Carlton', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109015799363771978289/photos">Brendan Josey</a>'], 'photo_reference': 'CmRaAAAAFdWdRvj07RC1dtzueJhcG9vVg0FVRP7Ob-pd-dWBU_gjfi0jxGiMkvH3FWOxa2TGDg3_SkKR8kegL7GJzpIfa_nHQVeZvTs4VWIweuy4gg1ctpeLxW13RLXsnsZ5hooCEhDpYOzCX6n_QPYFkiQ0Ypi-GhRT2gfF7dgfsQ1FYwUD-r86vZGNPw', 'width': 4032}], 'place_id': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'plus_code': {'compound_code': '6X29+Q8 Carlton, Victoria, Australia', 'global_code': '4RJ66X29+Q8'}, 'price_level': 1, 'rating': 4.1, 'reference': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Lygon Court, 368-380 Lygon St, Carlton'}, {'geometry': {'location': {'lat': -37.7927456, 'lng': 144.9695322}, 'viewport': {'northeast': {'lat': -37.79139577010728, 'lng': 144.9708820298927}, 'southwest': {'lat': -37.79409542989272, 'lng': 144.9681823701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'e6a9e86c14c769be1bee117d03a91394a5fc1692', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 3.2, 'reference': 'ChIJTbth3ChD1moRPzGE3uUQMD4', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Princes St & Drummond St, Carlton'}, {'geometry': {'location': {'lat': -37.7927445, 'lng': 144.9695346}, 'viewport': {'northeast': {'lat': -37.79132872010728, 'lng': 144.9702835298928}, 'southwest': {'lat': -37.79402837989272, 'lng': 144.9675838701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '98c15f97919ca08028ab3c43bb4a160534e592ab', 'name': 'IGA Supermarket', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJHbHg3yhD1moRtigMFWQSBaY', 'plus_code': {'compound_code': '6X49+WR Carlton, Victoria, Australia', 'global_code': '4RJ66X49+WR'}, 'rating': 0, 'reference': 'ChIJHbHg3yhD1moRtigMFWQSBaY', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '570 Lygon St, Carlton'}], 'status': 'OK'}
# (3, 0)
# 2
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7989008, 'lng': 144.9535724}, 'viewport': {'northeast': {'lat': -37.79750127010728, 'lng': 144.9549849798927}, 'southwest': {'lat': -37.80020092989272, 'lng': 144.9522853201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '72cb1b58bfa217cf59b7ede4336208003a82cddd', 'name': 'IGA X-press', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103599752797714148891/photos">Rodrigo del Busto</a>'], 'photo_reference': 'CmRaAAAAZJ_Xo2p5ulxfKH04LI9xK9DDNVvBpazMpxEV_E9cICrGvbD0IbOjcDJqgPGUuuMjwrDhZJFDPWBHt1LjppsJgsFSj_1Z8VvIApO7Kn9EDDiF4C16TZefmvahan_2daorEhDcSHhGs7kJZlzgLfWOiBbvGhTSybE4LPQTkB_biRZgJG6BxGdS8w', 'width': 4032}], 'place_id': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'plus_code': {'compound_code': '6X23+CC North Melbourne, Victoria, Australia', 'global_code': '4RJ66X23+CC'}, 'rating': 3.7, 'reference': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '75 Flemington Rd, North Melbourne'}, {'geometry': {'location': {'lat': -37.7982686, 'lng': 144.9465027}, 'viewport': {'northeast': {'lat': -37.79699792010727, 'lng': 144.9478365298927}, 'southwest': {'lat': -37.79969757989272, 'lng': 144.9451368701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'd20a6d08e35d7829698a88372367473d9957093e', 'name': 'North Melbourne Milk Bar & Wine Gourmet', 'place_id': 'ChIJ4bv-Ojtd1moR0Fxso3VWbdk', 'plus_code': {'compound_code': '6W2W+MJ North Melbourne, Victoria, Australia', 'global_code': '4RJ66W2W+MJ'}, 'rating': 3.4, 'reference': 'ChIJ4bv-Ojtd1moR0Fxso3VWbdk', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '48 Haines St, North Melbourne'}], 'status': 'OK'}
# (3, 1)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7989008, 'lng': 144.9535724}, 'viewport': {'northeast': {'lat': -37.79750127010728, 'lng': 144.9549849798927}, 'southwest': {'lat': -37.80020092989272, 'lng': 144.9522853201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '72cb1b58bfa217cf59b7ede4336208003a82cddd', 'name': 'IGA X-press', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103599752797714148891/photos">Rodrigo del Busto</a>'], 'photo_reference': 'CmRaAAAAqk0kxztRLyJWjmDJAkXPC3ittF7DyxVj9hOg7dEY64ruyrbLYAZ-IwdY4sHQMF1HbTED7Qf_7LiVRBpAubdSIfAFSFlr0ZPEqwvAqpPmXtejCp6q713A5I4pT-c518kSEhDNnzTqUsYMFi6u6ZdpG9pSGhRyChTlz1uWCydPblEtF_c7Wt9zbA', 'width': 4032}], 'place_id': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'plus_code': {'compound_code': '6X23+CC North Melbourne, Victoria, Australia', 'global_code': '4RJ66X23+CC'}, 'rating': 3.7, 'reference': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '75 Flemington Rd, North Melbourne'}], 'status': 'OK'}
# (3, 2)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7989008, 'lng': 144.9535724}, 'viewport': {'northeast': {'lat': -37.79750127010728, 'lng': 144.9549849798927}, 'southwest': {'lat': -37.80020092989272, 'lng': 144.9522853201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '72cb1b58bfa217cf59b7ede4336208003a82cddd', 'name': 'IGA X-press', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103599752797714148891/photos">Rodrigo del Busto</a>'], 'photo_reference': 'CmRaAAAAjYogZPZ_69FG8Ql-AdVXKem6viNnKwczihHXfiZsGZpuD8FZ7F9-sNNk5xQ36h4JWvjXLfDXNsVjd5s5apQhcuReNUeRPPIPoLGWHvWjFSQ6wV3HX4k_1QIyp1H5mE9HEhBPegS9dMsXV0XKnBZRcyZsGhSW_p179RleNXQyaLAZGhaw5Q3vNQ', 'width': 4032}], 'place_id': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'plus_code': {'compound_code': '6X23+CC North Melbourne, Victoria, Australia', 'global_code': '4RJ66X23+CC'}, 'rating': 3.7, 'reference': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '75 Flemington Rd, North Melbourne'}], 'status': 'OK'}
# (3, 3)
# 2
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7989008, 'lng': 144.9535724}, 'viewport': {'northeast': {'lat': -37.79750127010728, 'lng': 144.9549849798927}, 'southwest': {'lat': -37.80020092989272, 'lng': 144.9522853201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '72cb1b58bfa217cf59b7ede4336208003a82cddd', 'name': 'IGA X-press', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103599752797714148891/photos">Rodrigo del Busto</a>'], 'photo_reference': 'CmRaAAAAT0DCXDU_qjkhPgzS4n_3ltROMY0t-u3Q7JMa2MAx7PU_eXmTRQ9Jl9JFYYqTI8_H12I37ld1yJCXz5Er-YjLyYetxPebZchM_1BrqSJrbSxa3b3KPMTzjhAFCm_KEkL9EhBH4zbX_9pQzob_B7NrdDALGhRph2pxe2flMvzmf8ys3XM-AjBAHw', 'width': 4032}], 'place_id': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'plus_code': {'compound_code': '6X23+CC North Melbourne, Victoria, Australia', 'global_code': '4RJ66X23+CC'}, 'rating': 3.7, 'reference': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '75 Flemington Rd, North Melbourne'}, {'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (3, 4)
# 2
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}, {'geometry': {'location': {'lat': -37.7989008, 'lng': 144.9535724}, 'viewport': {'northeast': {'lat': -37.79750127010728, 'lng': 144.9549849798927}, 'southwest': {'lat': -37.80020092989272, 'lng': 144.9522853201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '72cb1b58bfa217cf59b7ede4336208003a82cddd', 'name': 'IGA X-press', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103599752797714148891/photos">Rodrigo del Busto</a>'], 'photo_reference': 'CmRaAAAAJUK4Twy9busJrqp2_yi4zCwCuRKlsuLY-XlX5ijMBg4rj7ZQfT5i5KTPXFX0r1bVyTcGix5lgKY4g8hmtNCkPyddMUodL6wL-gWgP3SZtTtOThikCH7aIzeioqQs1TH-EhB4I2lyA4pWNrakJqeuF0CdGhQVAUq4QTjaPlsOK1pE_z67jMdTaw', 'width': 4032}], 'place_id': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'plus_code': {'compound_code': '6X23+CC North Melbourne, Victoria, Australia', 'global_code': '4RJ66X23+CC'}, 'rating': 3.7, 'reference': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '75 Flemington Rd, North Melbourne'}], 'status': 'OK'}
# (3, 5)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (3, 6)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (3, 7)
# 2
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7980553, 'lng': 144.9682563}, 'viewport': {'northeast': {'lat': -37.79680162010728, 'lng': 144.9698671298927}, 'southwest': {'lat': -37.79950127989272, 'lng': 144.9671674701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '1f0cd36222a1424f0990f93a531616bfcb8cabf1', 'name': 'Woolworths Carlton', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109015799363771978289/photos">Brendan Josey</a>'], 'photo_reference': 'CmRaAAAALlYnH2yzswWf14LTyqI_kVjmSIU-cS5Dr5a9h4b9s0mfCCj4uD_DPSeqPFTxqyo6nBRzAmoZZkyzvvy0ojGJP0mLPYKjDB_vbOw5xgmi2I8I_aAn3G3PpfshleWH7a0oEhDVae8IVI2F6N56qlQutTezGhSB3t95SGhQDEHdj9_TjsnbTxsARg', 'width': 4032}], 'place_id': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'plus_code': {'compound_code': '6X29+Q8 Carlton, Victoria, Australia', 'global_code': '4RJ66X29+Q8'}, 'price_level': 1, 'rating': 4.1, 'reference': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Lygon Court, 368-380 Lygon St, Carlton'}, {'geometry': {'location': {'lat': -37.7968617, 'lng': 144.960401}, 'viewport': {'northeast': {'lat': -37.79551187010727, 'lng': 144.9617508298927}, 'southwest': {'lat': -37.79821152989271, 'lng': 144.9590511701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '58cffec687dbb585a1a1a752547d4b41d3da3bbe', 'name': 'FoodWorks Melbourne University', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'plus_code': {'compound_code': '6X36+75 Parkville, Victoria, Australia', 'global_code': '4RJ66X36+75'}, 'rating': 1.9, 'reference': 'ChIJ4cVgqixd1moRCnQEULE-5tM', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Union House, Melbourne University, G45 Swanston St, Parkville'}], 'status': 'OK'}
# (3, 8)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7980553, 'lng': 144.9682563}, 'viewport': {'northeast': {'lat': -37.79680162010728, 'lng': 144.9698671298927}, 'southwest': {'lat': -37.79950127989272, 'lng': 144.9671674701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '1f0cd36222a1424f0990f93a531616bfcb8cabf1', 'name': 'Woolworths Carlton', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109015799363771978289/photos">Brendan Josey</a>'], 'photo_reference': 'CmRaAAAARvffQlIb8OCzgTdd_B-WQUfofe9qQHZy8EWhg5y104fikWHK9A_xd7xxzHNx3siKBDNNhVM-fF5lYvdqMDCOn4RQwgt1ztxfdBDe3rZ-tP7hy9hhexmBCpgeIU4HtlpKEhDgioDCfRoqoH0UvN7sxmOGGhSS_oRiHdnwahZE8NzaWPndv36CDA', 'width': 4032}], 'place_id': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'plus_code': {'compound_code': '6X29+Q8 Carlton, Victoria, Australia', 'global_code': '4RJ66X29+Q8'}, 'price_level': 1, 'rating': 4.1, 'reference': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Lygon Court, 368-380 Lygon St, Carlton'}], 'status': 'OK'}
# (3, 9)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7980553, 'lng': 144.9682563}, 'viewport': {'northeast': {'lat': -37.79680162010728, 'lng': 144.9698671298927}, 'southwest': {'lat': -37.79950127989272, 'lng': 144.9671674701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '1f0cd36222a1424f0990f93a531616bfcb8cabf1', 'name': 'Woolworths Carlton', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109015799363771978289/photos">Brendan Josey</a>'], 'photo_reference': 'CmRaAAAAvWRE2-jH6C6z6xspdV-phFWrxfkVI_vPVaW36c5g9ZW5X7xw_J7eDzMX3Cd5gyt-u6U68m9jb305InG48Zk1ysiW-PJDkDX0QAVHA4CFsg89wN5UFuiFSsWUit6gykKNEhDe8ULGTReyUZ_ZlxLx2sUcGhQK8vEWk_vjUXoppYcz6AoiHIkkww', 'width': 4032}], 'place_id': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'plus_code': {'compound_code': '6X29+Q8 Carlton, Victoria, Australia', 'global_code': '4RJ66X29+Q8'}, 'price_level': 1, 'rating': 4.1, 'reference': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Lygon Court, 368-380 Lygon St, Carlton'}], 'status': 'OK'}
# (3, 10)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7980553, 'lng': 144.9682563}, 'viewport': {'northeast': {'lat': -37.79680162010728, 'lng': 144.9698671298927}, 'southwest': {'lat': -37.79950127989272, 'lng': 144.9671674701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '1f0cd36222a1424f0990f93a531616bfcb8cabf1', 'name': 'Woolworths Carlton', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109015799363771978289/photos">Brendan Josey</a>'], 'photo_reference': 'CmRaAAAAswQb648VzhPFOfEqAEzQ5YtI95Y8OF1f4lNSjF8lMmi5aoeXKwQuae7WSfv_0Nx6ervrZX464f1WalJ7_uhgjoVRKL0m38CdaUQbd7qlwVHboaKP1cZn7GFRvdiBbdWQEhD1IqaQtG6sQ9D0yS_eG3MwGhSCqtQGj7B436Cbub3SodZEYrVEnQ', 'width': 4032}], 'place_id': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'plus_code': {'compound_code': '6X29+Q8 Carlton, Victoria, Australia', 'global_code': '4RJ66X29+Q8'}, 'price_level': 1, 'rating': 4.1, 'reference': 'ChIJPwxYiNZC1moRfdORY6zd3fU', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': 'Lygon Court, 368-380 Lygon St, Carlton'}], 'status': 'OK'}
# (4, 0)
# 2
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7989008, 'lng': 144.9535724}, 'viewport': {'northeast': {'lat': -37.79750127010728, 'lng': 144.9549849798927}, 'southwest': {'lat': -37.80020092989272, 'lng': 144.9522853201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '72cb1b58bfa217cf59b7ede4336208003a82cddd', 'name': 'IGA X-press', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103599752797714148891/photos">Rodrigo del Busto</a>'], 'photo_reference': 'CmRaAAAA5AJ9MJTk-sQB3f65gdS2gUFsAfpL2ucBC1fRZPi7bsqdenbYpmokerbME5kwjpQ82jdzM9fw-_eGUFzwIOXu2PpdxUHe1qjH6D9Bv8bMLC36n4gSIjSmTsDT2kxqOslsEhAGcXOWpDEfJNSC7-I6EhrUGhRC07UdEI382kH-a3Sy7NDhxK876g', 'width': 4032}], 'place_id': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'plus_code': {'compound_code': '6X23+CC North Melbourne, Victoria, Australia', 'global_code': '4RJ66X23+CC'}, 'rating': 3.7, 'reference': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '75 Flemington Rd, North Melbourne'}, {'geometry': {'location': {'lat': -37.7982686, 'lng': 144.9465027}, 'viewport': {'northeast': {'lat': -37.79699792010727, 'lng': 144.9478365298927}, 'southwest': {'lat': -37.79969757989272, 'lng': 144.9451368701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'd20a6d08e35d7829698a88372367473d9957093e', 'name': 'North Melbourne Milk Bar & Wine Gourmet', 'place_id': 'ChIJ4bv-Ojtd1moR0Fxso3VWbdk', 'plus_code': {'compound_code': '6W2W+MJ North Melbourne, Victoria, Australia', 'global_code': '4RJ66W2W+MJ'}, 'rating': 3.4, 'reference': 'ChIJ4bv-Ojtd1moR0Fxso3VWbdk', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '48 Haines St, North Melbourne'}], 'status': 'OK'}
# (4, 1)
# 1
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.7989008, 'lng': 144.9535724}, 'viewport': {'northeast': {'lat': -37.79750127010728, 'lng': 144.9549849798927}, 'southwest': {'lat': -37.80020092989272, 'lng': 144.9522853201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '72cb1b58bfa217cf59b7ede4336208003a82cddd', 'name': 'IGA X-press', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103599752797714148891/photos">Rodrigo del Busto</a>'], 'photo_reference': 'CmRaAAAA6qs1EKXTXROVtNn2Rx3mz9Bb-fayZXvEl1HrEHXibQw4ki9zI0sE5Vy55rJu_eeEm_EyGyVPOhcQmf8999k9PDbCWbXZefyia7YIUGggzRAIB7zFjRPENtPu5qXwwGctEhDe7An-SPv4vBmxKyXPOqBmGhR2sdy7M1fwwX6sIVaZ4n1qokemFQ', 'width': 4032}], 'place_id': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'plus_code': {'compound_code': '6X23+CC North Melbourne, Victoria, Australia', 'global_code': '4RJ66X23+CC'}, 'rating': 3.7, 'reference': 'ChIJk1rXOy5d1moR46D0zicVgOI', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '75 Flemington Rd, North Melbourne'}], 'status': 'OK'}
# (4, 2)
# 1
# ...
# (10, 8)
# 8
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.8079222, 'lng': 144.9682901}, 'viewport': {'northeast': {'lat': -37.80653077010728, 'lng': 144.9697717298927}, 'southwest': {'lat': -37.80923042989272, 'lng': 144.9670720701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '434dce610de4a3c6f778e1cb2fa54dc06a2f0637', 'name': 'IGA', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2988, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111017160542645640601/photos">Chris Ware</a>'], 'photo_reference': 'CmRaAAAAyFVT03W8pdE4BCKc3JKfCxILTXxczSphAD0c6R-mtIbOJgszo4ioG47OCdbGjkKXm9D1Z9B1ulZ64ZaaWi5U1hLzMY19ZNV-LUYFvN7yOxgmI_a5FToWIWLrdZbdlW0PEhDXAIhQpfyWYY0omtSgFqZPGhT2dsWaU73A9c5qwa3FvvvfnUIUUg', 'width': 5312}], 'place_id': 'ChIJtUIS8c5C1moRMhwSsUaAxzg', 'plus_code': {'compound_code': '5XR9+R8 Melbourne, Victoria, Australia', 'global_code': '4RJ65XR9+R8'}, 'rating': 3.8, 'reference': 'ChIJtUIS8c5C1moRMhwSsUaAxzg', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '333 Exhibition St, Melbourne'}, {'geometry': {'location': {'lat': -37.8099763, 'lng': 144.9633857}, 'viewport': {'northeast': {'lat': -37.80862647010727, 'lng': 144.9647355298927}, 'southwest': {'lat': -37.81132612989272, 'lng': 144.9620358701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'b6d5ef7d475154fdaa9bda1dc7e699d6d7bceee7', 'name': 'Coles Melbourne Central', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2620, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108594547680977901282/photos">王性淵</a>'], 'photo_reference': 'CmRaAAAAJWvuddcDIfIagYqcztY2AE80ccVPlqmI5g5aFA4OoiBssONw1aZaz4YX2wkoDt-GTTdftjZFnGcKgS5xPobKTzvKiIkPBILJ-321hpg5amURQ8qRdM244ziITVSSKilTEhCX7FhK8DKUpSedgijnkKEqGhSZNCia_3egbmPbvTqT_xAa81rrSw', 'width': 4656}], 'place_id': 'ChIJ_0JfjMpC1moRzrJrakSZWIw', 'plus_code': {'compound_code': '5XR7+29 Melbourne, Victoria, Australia', 'global_code': '4RJ65XR7+29'}, 'rating': 3.8, 'reference': 'ChIJ_0JfjMpC1moRzrJrakSZWIw', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '211 La Trobe St, Melbourne'}, {'geometry': {'location': {'lat': -37.8111877, 'lng': 144.9650378}, 'viewport': {'northeast': {'lat': -37.80997562010727, 'lng': 144.9662116798928}, 'southwest': {'lat': -37.81267527989272, 'lng': 144.9635120201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'b1a3c251a902f9dc63d9245060d3e9a9a51ce9da', 'name': 'Woolworths Metro', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108664627381720099994/photos">A Google User</a>'], 'photo_reference': 'CmRZAAAAWxpnRD6K7EmfunExcNOdjpARIklIEa0ftogol7SObRj1o8Djx8CNPrL7XcioWdKVU_yr5F1xcmhvqaf01dfQ03ad0IcDA0dRF-KD8ySq_JvU997SUqFxOcukyen0dxIMEhBDHh1sxLgHSfASD0plBKWvGhRZECDa-k4yHkAhOVUiNjOqUEZTWA', 'width': 4032}], 'place_id': 'ChIJzXQ14cpC1moRnnC-9UE9ZxY', 'plus_code': {'compound_code': '5XQ8+G2 Melbourne, Victoria, Australia', 'global_code': '4RJ65XQ8+G2'}, 'price_level': 1, 'rating': 4, 'reference': 'ChIJzXQ14cpC1moRnnC-9UE9ZxY', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '183-201 La Trobe St, Melbourne'}, {'geometry': {'location': {'lat': -37.8074309, 'lng': 144.9622196}, 'viewport': {'northeast': {'lat': -37.80620097010728, 'lng': 144.9634321798927}, 'southwest': {'lat': -37.80890062989272, 'lng': 144.9607325201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '41d36eed69abed97bd8f306ec99ec1b1ac59783e', 'name': 'ALDI Melbourne CBD', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2448, 'html_attributions' ...
# (10, 9)
# 6
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.8079222, 'lng': 144.9682901}, 'viewport': {'northeast': {'lat': -37.80653077010728, 'lng': 144.9697717298927}, 'southwest': {'lat': -37.80923042989272, 'lng': 144.9670720701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '434dce610de4a3c6f778e1cb2fa54dc06a2f0637', 'name': 'IGA', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2988, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111017160542645640601/photos">Chris Ware</a>'], 'photo_reference': 'CmRaAAAAxeFyZ9AEKAs_bfMHUwI4rVcIuRih_qjLlk0jtuLixOT7P8IvZy1a5pzmtSFxTs7-vV9zAcIDwGJhg2Wlz-Izpx34piRhVautAWrh2R97OE-5WpRLfFY7KAPucY-XwLibEhA-uP-PDl1Gct_Z5vL7LmiJGhTgmOtu5FHPcvE3OrskypoD5Bde-g', 'width': 5312}], 'place_id': 'ChIJtUIS8c5C1moRMhwSsUaAxzg', 'plus_code': {'compound_code': '5XR9+R8 Melbourne, Victoria, Australia', 'global_code': '4RJ65XR9+R8'}, 'rating': 3.8, 'reference': 'ChIJtUIS8c5C1moRMhwSsUaAxzg', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '333 Exhibition St, Melbourne'}, {'geometry': {'location': {'lat': -37.8098337, 'lng': 144.9711351}, 'viewport': {'northeast': {'lat': -37.80845542010729, 'lng': 144.9724179798928}, 'southwest': {'lat': -37.81115507989273, 'lng': 144.9697183201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'd74c9bcee86a0cf6a01080a1d691f771874715d3', 'name': 'IGA X-press', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2448, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108024793198560180034/photos">Mick MSS Photography</a>'], 'photo_reference': 'CmRaAAAARyQY7nOhQBZ2ZCVLFVYa5fxmSwrZOQQud0Oaj21fLqLestzFkVm4ynxTYMz92lmPs1mV8QaJRHu67kKBd5UH0Wswj2wf0xgNW7zalwJxYEUSS9OkwrvfM0kHUeFd0FkdEhCS9IShq5F9x2BA9tHmd7dxGhTHTx36kj8FWzfHyC4fFFYAEFvMJg', 'width': 3264}], 'place_id': 'ChIJt8vcQM9C1moRMNcMXOrTiI8', 'plus_code': {'compound_code': '5XRC+3F Melbourne, Victoria, Australia', 'global_code': '4RJ65XRC+3F'}, 'rating': 4.2, 'reference': 'ChIJt8vcQM9C1moRMNcMXOrTiI8', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '35/41 Lonsdale St, Melbourne'}, {'geometry': {'location': {'lat': -37.8111877, 'lng': 144.9650378}, 'viewport': {'northeast': {'lat': -37.80997562010727, 'lng': 144.9662116798928}, 'southwest': {'lat': -37.81267527989272, 'lng': 144.9635120201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'b1a3c251a902f9dc63d9245060d3e9a9a51ce9da', 'name': 'Woolworths Metro', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108664627381720099994/photos">A Google User</a>'], 'photo_reference': 'CmRZAAAAWVJFFKbHmX045w_R2LIh6icEJ0wwOWMU-c_VrmyskYHZebQthRPaYcbXNv5I0fK8JdC0jXWcXGXSWYDTEnit30mi1TVf3NOtpU_6t_R5Mt9nNYfeA8yPEAV0Q2iO51QJEhD6SJWQ0aWFmlJCT4Nm50rsGhTOYukMngcSNIhHsv7Fy6QwLaoe1g', 'width': 4032}], 'place_id': 'ChIJzXQ14cpC1moRnnC-9UE9ZxY', 'plus_code': {'compound_code': '5XQ8+G2 Melbourne, Victoria, Australia', 'global_code': '4RJ65XQ8+G2'}, 'price_level': 1, 'rating': 4, 'reference': 'ChIJzXQ14cpC1moRnnC-9UE9ZxY', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '183-201 La Trobe St, Melbourne'}, {'geometry': {'location': {'lat': -37.8111722, 'lng': 144.9648705}, 'viewport': {'northeast': {'lat': -37.80984002010727, 'lng': 144.9665066798927}, 'southwest': {'lat': -37.81253967989272, 'lng': 144.9638070201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'a3fec07f8d00f815f0578fe6fbdb2c613d48a468', 'name': 'Woolworths QV', 'opening_hours': {'open_now': True}, 'photos': [{'height': 4032, 'html_attribution ...
# (10, 10)
# 4
# places {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': -37.8098337, 'lng': 144.9711351}, 'viewport': {'northeast': {'lat': -37.80845542010729, 'lng': 144.9724179798928}, 'southwest': {'lat': -37.81115507989273, 'lng': 144.9697183201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'd74c9bcee86a0cf6a01080a1d691f771874715d3', 'name': 'IGA X-press', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2448, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108024793198560180034/photos">Mick MSS Photography</a>'], 'photo_reference': 'CmRaAAAAWoi2tROkOO1iatTvtYEccUIwrZR8RLayliY-guqjwRdk33R12GAKByZnxW4hukbM_kRSmmnWql5A_Cv_KkovY8BjbcyVikmlXe-8gzi5gBuGCxFxNImmGcZqALssftykEhDjPDzrnjve-14GXmWPI-o8GhR5UoCEKon7IEB3MpJVd1mnaa3vEA', 'width': 3264}], 'place_id': 'ChIJt8vcQM9C1moRMNcMXOrTiI8', 'plus_code': {'compound_code': '5XRC+3F Melbourne, Victoria, Australia', 'global_code': '4RJ65XRC+3F'}, 'rating': 4.2, 'reference': 'ChIJt8vcQM9C1moRMNcMXOrTiI8', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '35/41 Lonsdale St, Melbourne'}, {'geometry': {'location': {'lat': -37.8079222, 'lng': 144.9682901}, 'viewport': {'northeast': {'lat': -37.80653077010728, 'lng': 144.9697717298927}, 'southwest': {'lat': -37.80923042989272, 'lng': 144.9670720701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '434dce610de4a3c6f778e1cb2fa54dc06a2f0637', 'name': 'IGA', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2988, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111017160542645640601/photos">Chris Ware</a>'], 'photo_reference': 'CmRaAAAAGT9LH_eyvrwFQN-TQ-TTr-tJSqDdOfHCupeici1_UpuDRih51YgcMvbxT_BTwbnw6QCeeCOXkGTXyHE1IrTlmGWYg4EBlxYtWfjUqEMzl1QDRJxkq_ecQNZlwd-c0XyBEhCgGyuqoORjgre2cUYqVptMGhSyK41tQcmVt5WURn1pxwXFbzzwQQ', 'width': 5312}], 'place_id': 'ChIJtUIS8c5C1moRMhwSsUaAxzg', 'plus_code': {'compound_code': '5XR9+R8 Melbourne, Victoria, Australia', 'global_code': '4RJ65XR9+R8'}, 'rating': 3.8, 'reference': 'ChIJtUIS8c5C1moRMhwSsUaAxzg', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '333 Exhibition St, Melbourne'}, {'geometry': {'location': {'lat': -37.8107916, 'lng': 144.9659293}, 'viewport': {'northeast': {'lat': -37.80937082010728, 'lng': 144.9673091298927}, 'southwest': {'lat': -37.81207047989272, 'lng': 144.9646094701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '62e3d99f9882758fd6c93450f9d729f98a0c35a3', 'name': 'Safe Way Super Market', 'place_id': 'ChIJbyg0zstC1moRedsl1ZPfG8M', 'plus_code': {'compound_code': '5XQ8+M9 Melbourne, Victoria, Australia', 'global_code': '4RJ65XQ8+M9'}, 'rating': 1, 'reference': 'ChIJbyg0zstC1moRedsl1ZPfG8M', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '7 Artemis Ln, Melbourne'}, {'geometry': {'location': {'lat': -37.8102716, 'lng': 144.966642}, 'viewport': {'northeast': {'lat': -37.80889387010728, 'lng': 144.9679786798927}, 'southwest': {'lat': -37.81159352989272, 'lng': 144.9652790201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '65250a2eb9447bad26a8a18e6af329116445e29d', 'name': 'Laguna Oriental Supermarket', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106740121402864559797/photos">Nsy Dvn</a>'], 'photo_reference': 'CmRaAAAAMb924PLYt-DYFBnCvj-JtDGQd-abuR7cGJNq67OH-y4XqjBBC3nRaLab3Qv4aGS3FRwcWvJMacIVWE_NG0xOQ-V8-bccFJcqp94vqyRD_XA4PBCash_SoXlKO7u-9sbDEhBe5YSEcTsXlTCuT_2y9h2sGhR-x7gPGbOuYT-ewgXzSoSiwudNXA', 'width': 4032}], 'place_id': 'ChIJt9TRxMtC1moR-oKhszjxbDA', 'plus_code': {'compound_code': '5XQ8+VM Melbourne, V ...
# ##finished

# %%
#records
#import json

#RecordsAll1=[]
#with open(t+'_supermarketset.json', 'w') as f:
#    json.dump(RecordsAll1, f)
print (places['results'])
# Out:
# [{'geometry': {'location': {'lat': -37.8098337, 'lng': 144.9711351}, 'viewport': {'northeast': {'lat': -37.80845542010729, 'lng': 144.9724179798928}, 'southwest': {'lat': -37.81115507989273, 'lng': 144.9697183201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': 'd74c9bcee86a0cf6a01080a1d691f771874715d3', 'name': 'IGA X-press', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2448, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108024793198560180034/photos">Mick MSS Photography</a>'], 'photo_reference': 'CmRaAAAAWoi2tROkOO1iatTvtYEccUIwrZR8RLayliY-guqjwRdk33R12GAKByZnxW4hukbM_kRSmmnWql5A_Cv_KkovY8BjbcyVikmlXe-8gzi5gBuGCxFxNImmGcZqALssftykEhDjPDzrnjve-14GXmWPI-o8GhR5UoCEKon7IEB3MpJVd1mnaa3vEA', 'width': 3264}], 'place_id': 'ChIJt8vcQM9C1moRMNcMXOrTiI8', 'plus_code': {'compound_code': '5XRC+3F Melbourne, Victoria, Australia', 'global_code': '4RJ65XRC+3F'}, 'rating': 4.2, 'reference': 'ChIJt8vcQM9C1moRMNcMXOrTiI8', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '35/41 Lonsdale St, Melbourne'}, {'geometry': {'location': {'lat': -37.8079222, 'lng': 144.9682901}, 'viewport': {'northeast': {'lat': -37.80653077010728, 'lng': 144.9697717298927}, 'southwest': {'lat': -37.80923042989272, 'lng': 144.9670720701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '434dce610de4a3c6f778e1cb2fa54dc06a2f0637', 'name': 'IGA', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2988, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111017160542645640601/photos">Chris Ware</a>'], 'photo_reference': 'CmRaAAAAGT9LH_eyvrwFQN-TQ-TTr-tJSqDdOfHCupeici1_UpuDRih51YgcMvbxT_BTwbnw6QCeeCOXkGTXyHE1IrTlmGWYg4EBlxYtWfjUqEMzl1QDRJxkq_ecQNZlwd-c0XyBEhCgGyuqoORjgre2cUYqVptMGhSyK41tQcmVt5WURn1pxwXFbzzwQQ', 'width': 5312}], 'place_id': 'ChIJtUIS8c5C1moRMhwSsUaAxzg', 'plus_code': {'compound_code': '5XR9+R8 Melbourne, Victoria, Australia', 'global_code': '4RJ65XR9+R8'}, 'rating': 3.8, 'reference': 'ChIJtUIS8c5C1moRMhwSsUaAxzg', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '333 Exhibition St, Melbourne'}, {'geometry': {'location': {'lat': -37.8107916, 'lng': 144.9659293}, 'viewport': {'northeast': {'lat': -37.80937082010728, 'lng': 144.9673091298927}, 'southwest': {'lat': -37.81207047989272, 'lng': 144.9646094701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '62e3d99f9882758fd6c93450f9d729f98a0c35a3', 'name': 'Safe Way Super Market', 'place_id': 'ChIJbyg0zstC1moRedsl1ZPfG8M', 'plus_code': {'compound_code': '5XQ8+M9 Melbourne, Victoria, Australia', 'global_code': '4RJ65XQ8+M9'}, 'rating': 1, 'reference': 'ChIJbyg0zstC1moRedsl1ZPfG8M', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment'], 'vicinity': '7 Artemis Ln, Melbourne'}, {'geometry': {'location': {'lat': -37.8102716, 'lng': 144.966642}, 'viewport': {'northeast': {'lat': -37.80889387010728, 'lng': 144.9679786798927}, 'southwest': {'lat': -37.81159352989272, 'lng': 144.9652790201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': '65250a2eb9447bad26a8a18e6af329116445e29d', 'name': 'Laguna Oriental Supermarket', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106740121402864559797/photos">Nsy Dvn</a>'], 'photo_reference': 'CmRaAAAAMb924PLYt-DYFBnCvj-JtDGQd-abuR7cGJNq67OH-y4XqjBBC3nRaLab3Qv4aGS3FRwcWvJMacIVWE_NG0xOQ-V8-bccFJcqp94vqyRD_XA4PBCash_SoXlKO7u-9sbDEhBe5YSEcTsXlTCuT_2y9h2sGhR-x7gPGbOuYT-ewgXzSoSiwudNXA', 'width': 4032}], 'place_id': 'ChIJt9TRxMtC1moR-oKhszjxbDA', 'plus_code': {'compound_code': '5XQ8+VM Melbourne, Victoria, Australia', 'global_code': '4RJ65XQ ...

# %%
RecordidAll={}
count=0
for cell in RecordsAll:
    for place in cell:

        place_id=place['place_id'].encode('utf-8')
        if place_id not in RecordidAll.keys():
            RecordidAll[place_id]=place
        else:
            print (place_id)
            count=count+1
print (count)
RecordsAll1=RecordidAll.values()
with open(t+'_supermarket.json', 'w') as f:
    json.dump(list(RecordsAll1), f)
# Out:
# b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# b'ChIJHbHg3yhD1moRtigMFWQSBaY'
# b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# b'ChIJHbHg3yhD1moRtigMFWQSBaY'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# b'ChIJHbHg3yhD1moRtigMFWQSBaY'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# b'ChIJHbHg3yhD1moRtigMFWQSBaY'
# b'ChIJ4bv-Ojtd1moR0Fxso3VWbdk'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJ4bv-Ojtd1moR0Fxso3VWbdk'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJIfNSG2Ng1moRYk-qZ7N6uP0'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJ4bv-Ojtd1moR0Fxso3VWbdk'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJY5FAHjpd1moR384cT3h_l2I'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJ4cVgqixd1moRCnQEULE-5tM'
# b'ChIJIfNSG2Ng1moRYk-qZ7N6uP0'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJIfNSG2Ng1moRYk-qZ7N6uP0'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJPwxYiNZC1moRfdORY6zd3fU'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJY5FAHjpd1moR384cT3h_l2I'
# b'ChIJ4bv-Ojtd1moR0Fxso3VWbdk'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJY5FAHjpd1moR384cT3h_l2I'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJk1rXOy5d1moR46D0zicVgOI'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJY5FAHjpd1moR384cT3h_l2I'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJY5FAHjpd1moR384cT3h_l2I'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJY5FAHjpd1moR384cT3h_l2I'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJY5FAHjpd1moR384cT3h_l2I'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJK2Z8s8xC1moRwINOqvAsuKo'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJY5FAHjpd1moR384cT3h_l2I'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJY5FAHjpd1moR384cT3h_l2I'
# b'ChIJ0d8G3jld1moRSqOGRQCTe84'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJJZeaKstC1moRe65yHj6fGEw'
# b'ChIJK2Z8s8xC1moRwINOqvAsuKo'
# b'ChIJG-q_PstC1moR1PuKIms880k'
# b'ChIJD9BELDVd1moRsQZ9lvq7Wdo'
# b'ChIJkbaCyzRd1moR2saNLhVZV4w'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJJZeaKstC1moRe65yHj6fGEw'
# b'ChIJ_0JfjMpC1moRzrJrakSZWIw'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJK2Z8s8xC1moRwINOqvAsuKo'
# b'ChIJG-q_PstC1moR1PuKIms880k'
# b'ChIJD9BELDVd1moRsQZ9lvq7Wdo'
# b'ChIJkbaCyzRd1moR2saNLhVZV4w'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJ_0JfjMpC1moRzrJrakSZWIw'
# b'ChIJJZeaKstC1moRe65yHj6fGEw'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJD9BELDVd1moRsQZ9lvq7Wdo'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJ_0JfjMpC1moRzrJrakSZWIw'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJG-q_PstC1moR1PuKIms880k'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJt8vcQM9C1moRMNcMXOrTiI8'
# b'ChIJfftV981C1moRSVnIw92Cp_E'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJJZeaKstC1moRe65yHj6fGEw'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJOWYRbjZd1moRWHO4MYko8n8'
# b'ChIJD9BELDVd1moRsQZ9lvq7Wdo'
# b'ChIJkbaCyzRd1moR2saNLhVZV4w'
# b'ChIJJZeaKstC1moRe65yHj6fGEw'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJ_0JfjMpC1moRzrJrakSZWIw'
# b'ChIJkbaCyzRd1moR2saNLhVZV4w'
# b'ChIJD9BELDVd1moRsQZ9lvq7Wdo'
# b'ChIJG-q_PstC1moR1PuKIms880k'
# b'ChIJK2Z8s8xC1moRwINOqvAsuKo'
# b'ChIJJZeaKstC1moRe65yHj6fGEw'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJ_0JfjMpC1moRzrJrakSZWIw'
# b'ChIJG-q_PstC1moR1PuKIms880k'
# b'ChIJkbaCyzRd1moR2saNLhVZV4w'
# b'ChIJD9BELDVd1moRsQZ9lvq7Wdo'
# b'ChIJK2Z8s8xC1moRwINOqvAsuKo'
# b'ChIJ_0JfjMpC1moRzrJrakSZWIw'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJJZeaKstC1moRe65yHj6fGEw'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJzXQ14cpC1moRnnC-9UE9ZxY'
# b'ChIJkZW8RMpC1moRixH-wBRZiRg'
# b'ChIJbyg0zstC1moRedsl1ZPfG8M'
# b'ChIJD9BELDVd1moRsQZ9lvq7Wdo'
# b'ChIJt9TRxMtC1moR-oKhszjxbDA'
# b'ChIJG-q_PstC1moR1PuKIms880k'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJ_0JfjMpC1moRzrJrakSZWIw'
# b'ChIJzXQ14cpC1moRnnC-9UE9ZxY'
# b'ChIJi4BYp8xC1moRLGHP3_UQ7Lg'
# b'ChIJkZW8RMpC1moRixH-wBRZiRg'
# b'ChIJbyg0zstC1moRedsl1ZPfG8M'
# b'ChIJG-q_PstC1moR1PuKIms880k'
# b'ChIJt9TRxMtC1moR-oKhszjxbDA'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJt8vcQM9C1moRMNcMXOrTiI8'
# b'ChIJzXQ14cpC1moRnnC-9UE9ZxY'
# b'ChIJkZW8RMpC1moRixH-wBRZiRg'
# b'ChIJbyg0zstC1moRedsl1ZPfG8M'
# b'ChIJt9TRxMtC1moR-oKhszjxbDA'
# b'ChIJt8vcQM9C1moRMNcMXOrTiI8'
# b'ChIJtUIS8c5C1moRMhwSsUaAxzg'
# b'ChIJbyg0zstC1moRedsl1ZPfG8M'
# b'ChIJt9TRxMtC1moR-oKhszjxbDA'
# 207

# %%
y,x
# Out:
# (-37.80822007795944, 144.97039725311325)

# %% [markdown]
# ### Parse data with Pandas

# %%
#import datetime
#datetime.datetime.now().strftime("%Y-%m-%d %H-%M-%S")

with open('data.json', 'w') as f:
    json.dump(places, f)

# %%
df = pd.DataFrame(columns=['name', 'lat', 'lon', 'rating','price_level','place_id','types'])
for cell in RecordsAll:
    for place in cell:
        #print(place)
        name = place['name'].encode('utf-8')
        lat = place['geometry']['location']['lat']
        lon = place['geometry']['location']['lng']
        place_id=place['place_id'].encode('utf-8')
        types=place['types']
        rating=place.get('rating','')
        price_level=place.get('price_level','')
        #address=place['formatted_address'].encode('utf-8')
        '''try:
            rating = place['rating'] #Not all places have ratings, so use try - except
            price_level=place['price_level']
        except:
            rating = ''
            price_level= '''''
        series = pd.Series([name, lat, lon, rating,price_level,place_id,types], index=['name', 'lat', 'lon', 'rating',
                                                                                       'price_level','place_id','types'])
        df = df.append(series,  ignore_index=True)
print(name, lat, lon, rating,price_level,place_id,types)
# Out:
# b'Laguna Oriental Supermarket' -37.8102716 144.966642 4.3  b'ChIJt9TRxMtC1moR-oKhszjxbDA' ['grocery_or_supermarket', 'store', 'point_of_interest', 'food', 'establishment']

# %%
#Take a quick look at our data frame
df.head()
# Out:
#                                 name        lat         lon  rating  \
# 0                 b'IGA Supermarket' -37.792746  144.969532     3.2
# 1                 b'IGA Supermarket' -37.792744  144.969535     0.0
# 2                 b'IGA Supermarket' -37.792746  144.969532     3.2
# 3                 b'IGA Supermarket' -37.792746  144.969532     3.2
# 4  b'FoodWorks Melbourne University' -37.796862  144.960401     1.9
#
#   price_level                        place_id  \
# 0              b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# 1              b'ChIJHbHg3yhD1moRtigMFWQSBaY'
# 2              b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# 3              b'ChIJTbth3ChD1moRPzGE3uUQMD4'
# 4              b'ChIJ4cVgqixd1moRCnQEULE-5tM'
#
#                                                types
# 0  [supermarket, grocery_or_supermarket, store, p...
# 1  [supermarket, grocery_or_supermarket, store, p...
# 2  [supermarket, grocery_or_supermarket, store, p...
# 3  [supermarket, grocery_or_supermarket, store, p...
# 4  [supermarket, grocery_or_supermarket, store, p...

# %%
#Drop duplicates
df2 = df.drop_duplicates('place_id')
df2.shape
# Out:
# (24, 7)

# %%
#output to csv
df2.to_csv(t+'_supermarket.csv')
